# %%
from __future__ import unicode_literals
import json 
import requests
import pandas 
import os
import youtube_dl
import numpy as np
import time

# %%
# Function to load json file
def loadKeys(key_file:str):
    with open(key_file) as f:
        key_dict = json.load(f)
    return key_dict['api_key'], key_dict['api_secret'], key_dict['bearer_token'], key_dict['token'], key_dict['token_secret']

# %%
# Creating a url for the api to search from
def createFirstSearchURL(wordSearch:str):
    query = '(%23{}) -is:retweet has:media -has:videos lang:en  -is:retweet'.format(wordSearch)
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    tweet_fields = "media.fields=type,url"
    expansions = "expansions=attachments.media_keys"
    max_results = "max_results=100"
    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}&{}&{}".format(
        query, tweet_fields, expansions, max_results
    )
    return url

# %%
# Creating a url for the api to search from
def createSearchURL(wordSearch:str, token:str):
    query = '(%23{}) -is:retweet has:media -has:videos lang:en  -is:retweet'.format(wordSearch)
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    nextToken = "next_token={}".format(token)
    tweet_fields = "media.fields=type,url"
    expansions = "expansions=attachments.media_keys"
    max_results = "max_results=100"
    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}&{}&{}&{}".format(
        query, tweet_fields, expansions, max_results, nextToken
    )
    return url

# %%
# Creating a url for the api to search from
def getSearchRequestCount(headers:str):
    url = "https://api.twitter.com/1.1/application/rate_limit_status.json?"
    data = connect_to_endpoint(url, headers)
    return int(data['resources']['search']['/search/tweets']['remaining'])

# %%
# Creating authorization 
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
# Connectign to the url api with the token headers
def connect_to_endpoint(url, headers):
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
# Creating json file from a response file and filename
def create_json(filename, json_response):
    with open(filename, "w") as write_file:
        json.dump(json_response, write_file, indent=4)

# %%
# loading up data of a json file
def load_json(filename):
    file = open(filename)
    data = json.load(file)
    file.close()
    return data

# %%
# Downloading gif file with given url 
def downloadGIF(url, filename):
    try:
        ydl_opts = {
            'outtmpl': 'gifs/{}.mp4'.format(filename)
        }
        with youtube_dl.YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
        return True
    except:
        print("Could Not Download File")
        return False

# %%
# Class TweetData holds the mediaKey, TweetURL, Text, TweetID for one data object in a json file
class TweetData:
    def __init__(self, jsonData):
        # Media Key Of Tweet
        mediaKey = jsonData['attachments']['media_keys'][0]
        # Splitting the text into the text and url
        tempTextArray = jsonData['text'].rpartition("https://")
        # Creating URL
        tweetURL = tempTextArray[1] + tempTextArray[2]
        # Creating tweet text
        text = tempTextArray[0]
        # Setting mediaKey, URL, and text
        self.mediaKey = mediaKey
        self.tweetURL = tweetURL
        self.text = text
        self.tweetID = jsonData['id']

# %%
# Create CSVandGIFS 
def createDFandGIFS(data:dict, finalTweetDF:pandas.DataFrame):
    # Headers for the data
    headers = ["Tweet ID", "Media Key", "Tweet URL", "Tweet Text", "GIF Title"]
    # Initializing 2d array that will contain all of the data
    tweetData = np.array([headers])   
    # Iterate over all of the collected tweets
    for temp in data['data']:
        
        try:# Creating a tweet obejct that holds the data
            tempTweet = TweetData(temp)
            # Check if the current media tweet contains a gif
            if "16_" in tempTweet.mediaKey: 
                # Create File Name
                curGifTitle =  "{}".format(tempTweet.mediaKey)
                # Try to download new file, if an error occurs and cant download gif, the file is not added
                if downloadGIF(tempTweet.tweetURL, curGifTitle):
                    # If Downloading causes no error we add this twitter obeject to our array 
                    # Create a numpy row to add to data
                    curRow = np.array([[
                        tempTweet.tweetID,
                        tempTweet.mediaKey,
                        tempTweet.tweetURL,
                        tempTweet.text,
                        curGifTitle + ".mp4"
                    ]])
                    # Adding indivisual data to whole data
                    tweetData = np.append(tweetData, curRow, axis=0)   
        except:
            print("Error with tweet")
    #Create a pandas file of the 
    tweetDF = pandas.DataFrame(data = tweetData[1:,:],  columns=tweetData[0])
    finalTweetDF = finalTweetDF.append(tweetDF, ignore_index=True)

    return finalTweetDF

# %%
# Main Scraper function 
def scraper(query:str , bearer_token:str , csvFileName:str, dataFileName:str):
    # Loading current csv file into a pandas data frame
    finalTwitterDF = pandas.read_csv(csvFileName)
    # Headers for the endpoint connection
    headers = create_headers(bearer_token)
    # Instantiating capCounter
    capCounter = 450000
    # Gets the total ammount of searches allowed with in the current 15 minute time frame. default = 450
    searchLimit = getSearchRequestCount(headers)
    firstSearch = True
    # Looping through twitter api and ensuring rate limits have not been exceeded
    while True:
        # Creating twitter api url on first and subsequent tries
        if firstSearch:
            url = createFirstSearchURL(query)
            firstSearch = False 
        else:
            if "next_token" in data["meta"].keys(): 
                nextToken = data["meta"]["next_token"] 
            else:
                return finalTwitterDF
            url = createSearchURL(query, nextToken) #<------ edit
        # Data collected from twitter api
        data = connect_to_endpoint(url, headers)
        # Saving previously used data as json file 
        create_json(dataFileName, data)
        # Updates df with newly  collected data
        finalTwitterDF = createDFandGIFS(data, finalTwitterDF)
        # Subtract one from the seachres
        searchLimit -= 1
        capCounter -= 100
        finalTwitterDF.to_csv(CSV_FILE_NAME, index=False)
        if capCounter < 100:
            return finalTwitterDF
        if searchLimit ==  0:
            time.sleep(60 * 15) # wait for 15 minutes so that we can reset the rate limits

# %%
# Creating keys for the twitter api
api_key, api_secret, bear_token, token, token_secret = loadKeys("keys.json")
bearer_token = bear_token
# CSV File Name
CSV_FILE_NAME = "twitterData.csv"
DATA_FILE_NAME = "data_file.json"
QUERY = "sad"
df = scraper(QUERY, bear_token, CSV_FILE_NAME, DATA_FILE_NAME)
# Out:
# wnload] gifs\16_1370353476258164739.mp4 has already been downloaded
# [download] 100% of 185.61KiB
# [generic] 2RzqfGq4NC: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 2RzqfGq4NC: Downloading webpage
# [generic] 2RzqfGq4NC: Extracting information
# [redirect] Following redirect to https://twitter.com/TsunaYosh_Kun/status/1370281423215599617/photo/1
# [twitter] 1370281423215599617: Downloading guest token
# [twitter] 1370281423215599617: Downloading JSON metadata
# [download] gifs\16_1370281413426081792.mp4 has already been downloaded
# [download] 100% of 14.88KiB
# [generic] rEaljML642: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] rEaljML642: Downloading webpage
# [generic] rEaljML642: Extracting information
# [redirect] Following redirect to https://twitter.com/usniffglue/status/1370253387296608256/photo/1
# [twitter] 1370253387296608256: Downloading guest token
# [twitter] 1370253387296608256: Downloading JSON metadata
# [download] gifs\16_1370253382036901895.mp4 has already been downloaded
# [download] 100% of 10.06KiB
# [generic] UlxwawhoD2: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] UlxwawhoD2: Downloading webpage
# [generic] UlxwawhoD2: Extracting information
# [redirect] Following redirect to https://twitter.com/Memysel26053299/status/1370222503566581764/photo/1
# [twitter] 1370222503566581764: Downloading guest token
# [twitter] 1370222503566581764: Downloading JSON metadata
# [download] gifs\16_1370222496209760260.mp4 has already been downloaded
# [download] 100% of 41.99KiB
# [generic] O51jJaWu6r: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] O51jJaWu6r: Downloading webpage
# [generic] O51jJaWu6r: Extracting information
# [redirect] Following redirect to https://twitter.com/EMBII4U/status/1370212561271021571/photo/1
# [twitter] 1370212561271021571: Downloading guest token
# [twitter] 1370212561271021571: Downloading JSON metadata
# [download] gifs\16_1370212555050860549.mp4 has already been downloaded
# [download] 100% of 13.39KiB
# [generic] 7D6SkV05rt: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 7D6SkV05rt: Downloading webpage
# [generic] 7D6SkV05rt: Extracting information
# [redirect] Following redirect to https://twitter.com/CRodriguezC12/status/1370211182452293634/photo/1
# [twitter] 1370211182452293634: Downloading guest token
# [twitter] 1370211182452293634: Downloading JSON metadata
# [download] gifs\16_1370211171979104256.mp4 has already been downloaded
# [download] 100% of 16.07KiB
# [generic] aFAklTkkH5: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] aFAklTkkH5: Downloading webpage
# [generic] aFAklTkkH5: Extracting information
# [redirect] Following redirect to https://twitter.com/TheMostMAGA/status/1370193193820635137/photo/1
# [twitter] 1370193193820635137: Downloading guest token
# [twitter] 1370193193820635137: Downloading JSON metadata
# [download] gifs\16_1370193187290152962.mp4 has already been downloaded
# [download] 100% of 29.15KiB
# [generic] tBDLzXnVyb: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] tBDLzXnVyb: Downloading webpage
# [generic] tBDLzXnVyb: Extracting information
# [redirect] Following redirect to https://twitter.com/Memysel26053299/status/1370182800112975874/photo/1
# [twitter] 1370182800112975874: Downloading guest token
# [twitter] 1370182800112975874: Downloading JSON metadata
# [download] gifs\16_1370182792672210954.mp4 has already been downloaded
# [download] 100% of 21.32KiB
# [generic] 97T9klrsnn: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 97T9klrsnn: Downloading webpage
# [generic] 97T9klrsnn: Extracting information
# [redirect] Following redirect to https://twitter.com/PunFuMaster/status/1370179553604276224/photo/1
# [twitter] 1370179553604276224: Downloading guest token
# [twitter] 1370179553604276224: Downloading JSON metadata
# [download] gifs\16_1370179539662426116.mp4 has already been downloaded
# [download] 100% of 14.02KiB
# [generic] Hek5xPYhgo: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] Hek5xPYhgo: Downloading webpage
# [generic] Hek5xPYhgo: Extracting information
# [redirect] Following redirect to https://twitter.com/ImpactiveEarth/status/1370165107557302272/photo/1
# [twitter] 1370165107557302272: Downloading guest token
# [twitter] 1370165107557302272: Downloading JSON metadata
# [download] gifs\16_1370165101588779025.mp4 has already been downloaded
# [download] 100% of 290.41KiB
# [generic] GvdaHqoSkz: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] GvdaHqoSkz: Downloading webpage
# [generic] GvdaHqoSkz: Extracting information
# [redirect] Following redirect to https://twitter.com/MoonshineDlight/status/1370156602058227713/photo/1
# [twitter] 1370156602058227713: Downloading guest token
# [twitter] 1370156602058227713: Downloading JSON metadata
# [download] gifs\16_1370156596161052681.mp4 has already been downloaded
# [download] 100% of 73.44KiB
# [generic] J1nTpNPUGq: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] J1nTpNPUGq: Downloading webpage
# [generic] J1nTpNPUGq: Extracting information
# [redirect] Following redirect to https://twitter.com/RobertJ95156615/status/1370150796390768640/photo/1
# [twitter] 1370150796390768640: Downloading guest token
# [twitter] 1370150796390768640: Downloading JSON metadata
# [download] gifs\16_1370149993001197573.mp4 has already been downloaded
# [download] 100% of 73.66KiB
# [generic] hAXoEaAAhw: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] hAXoEaAAhw: Downloading webpage
# [generic] hAXoEaAAhw: Extracting information
# [redirect] Following redirect to https://twitter.com/justanotherbobu/status/1370140711106932738/photo/1
# [twitter] 1370140711106932738: Downloading guest token
# [twitter] 1370140711106932738: Downloading JSON metadata
# [download] gifs\16_1370136740929830914.mp4 has already been downloaded
# [download] 100% of 16.96KiB
# [generic] cUNNyOGofL: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] cUNNyOGofL: Downloading webpage
# [generic] cUNNyOGofL: Extracting information
# [redirect] Following redirect to https://twitter.com/conn0rstrange/status/1370132823428849666/photo/1
# [twitter] 1370132823428849666: Downloading guest token
# [twitter] 1370132823428849666: Downloading JSON metadata
# [download] gifs\16_1370132817561067527.mp4 has already been downloaded
# [download] 100% of 23.75KiB
# [generic] i3PWkWw5Ce: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] i3PWkWw5Ce: Downloading webpage
# [generic] i3PWkWw5Ce: Extracting information
# [redirect] Following redirect to https://twitter.com/conn0rstrange/status/1370128230238232578/photo/1
# [twitter] 1370128230238232578: Downloading guest token
# [twitter] 1370128230238232578: Downloading JSON metadata
# [download] gifs\16_1370128224877826051.mp4 has already been downloaded
# [download] 100% of 65.86KiB
# [generic] QObuf772g2: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] QObuf772g2: Downloading webpage
# [generic] QObuf772g2: Extracting information
# [redirect] Following redirect to https://twitter.com/lil_doc_b/status/1370101167443824648/photo/1
# [twitter] 1370101167443824648: Downloading guest token
# [twitter] 1370101167443824648: Downloading JSON metadata
# [download] gifs\16_1370101160846184451.mp4 has already been downloaded
# [download] 100% of 34.09KiB
# [generic] i1JPWEtkpa: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] i1JPWEtkpa: Downloading webpage
# [generic] i1JPWEtkpa: Extracting information
# [redirect] Following redirect to https://twitter.com/Kacey325/status/1370100244843745280/photo/1
# [twitter] 1370100244843745280: Downloading guest token
# [twitter] 1370100244843745280: Downloading JSON metadata
# [download] gifs\16_1370100239441485824.mp4 has already been downloaded
# [download] 100% of 115.05KiB
# 200
# [generic] UY89Oz2qaR: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] UY89Oz2qaR: Downloading webpage
# [generic] UY89Oz2qaR: Extracting information
# [redirect] Following redirect to https://twitter.com/BrettSomers111/status/1370093348925620229/photo/1
# [twitter] 1370093348925620229: Downloading guest token
# [twitter] 1370093348925620229: Downloading JSON metadata
# [download] gifs\16_1370093342206332928.mp4 has already been downloaded
# [download] 100% of 53.20KiB
# [generic] moVw945MTa: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] moVw945MTa: Downloading webpage
# [generic] moVw945MTa: Extracting information
# [redirect] Following redirect to https://twitter.com/Graeme2796/status/1370052095869644803/photo/1
# [twitter] 1370052095869644803: Downloading guest token
# [twitter] 1370052095869644803: Downloading JSON metadata
# [download] gifs\16_1370052088059805700.mp4 has already been downloaded
# [download] 100% of 53.54KiB
# [generic] f6sd476Y7l: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] f6sd476Y7l: Downloading webpage
# [generic] f6sd476Y7l: Extracting information
# [redirect] Following redirect to https://twitter.com/zunderwhelmed/status/1370046482951311367/photo/1
# [twitter] 1370046482951311367: Downloading guest token
# [twitter] 1370046482951311367: Downloading JSON metadata
# [download] gifs\16_1370046470519422982.mp4 has already been downloaded
# [download] 100% of 81.76KiB
# [generic] lPeMmXx9hx: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] lPeMmXx9hx: Downloading webpage
# [generic] lPeMmXx9hx: Extracting information
# [redirect] Following redirect to https://twitter.com/LikejDoit/status/1370044802088177673/photo/1
# [twitter] 1370044802088177673: Downloading guest token
# [twitter] 1370044802088177673: Downloading JSON metadata
# [download] gifs\16_1370044791631847424.mp4 has already been downloaded
# [download] 100% of 29.38KiB
# [generic] Y7IjC8z8U0: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] Y7IjC8z8U0: Downloading webpage
# [generic] Y7IjC8z8U0: Extracting information
# [redirect] Following redirect to https://twitter.com/Tzunami_Sapp/status/1370040744132632584/photo/1
# [twitter] 1370040744132632584: Downloading guest token
# [twitter] 1370040744132632584: Downloading JSON metadata
# [download] gifs\16_1370040738529095681.mp4 has already been downloaded
# [download] 100% of 45.10KiB
# [generic] 4E0GbCRIxl: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 4E0GbCRIxl: Downloading webpage
# [generic] 4E0GbCRIxl: Extracting information
# [redirect] Following redirect to https://twitter.com/Capricious33/status/1370036482132512773/photo/1
# [twitter] 1370036482132512773: Downloading guest token
# [twitter] 1370036482132512773: Downloading JSON metadata
# [download] gifs\16_1370036476692500486.mp4 has already been downloaded
# [download] 100% of 4.21KiB
# [generic] iHjma4Hm4y: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] iHjma4Hm4y: Downloading webpage
# [generic] iHjma4Hm4y: Extracting information
# [redirect] Following redirect to https://twitter.com/paulmmace/status/1369987374885797889/photo/1
# [twitter] 1369987374885797889: Downloading guest token
# [twitter] 1369987374885797889: Downloading JSON metadata
# [download] gifs\16_1369987368036483073.mp4 has already been downloaded
# [download] 100% of 30.85KiB
# [generic] hztQHO8hQ0: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] hztQHO8hQ0: Downloading webpage
# [generic] hztQHO8hQ0: Extracting information
# [redirect] Following redirect to https://twitter.com/talkofthecharts/status/1369952674666323970
# [twitter] 1369952674666323970: Downloading guest token
# [twitter] 1369952674666323970: Downloading JSON metadata
# ERROR: There's no video in this tweet.; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# Could Not Download File
# [generic] 0lnQdme086: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 0lnQdme086: Downloading webpage
# [generic] 0lnQdme086: Extracting information
# [redirect] Following redirect to https://twitter.com/whoisEllio/status/1369932797692026882/photo/1
# [twitter] 1369932797692026882: Downloading guest token
# [twitter] 1369932797692026882: Downloading JSON metadata
# [download] gifs\16_1369932789752156160.mp4 has already been downloaded
# [download] 100% of 51.25KiB
# [generic] tzJPfzXoem: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] tzJPfzXoem: Downloading webpage
# [generic] tzJPfzXoem: Extracting information
# [redirect] Following redirect to https://twitter.com/MzToyzTweetz/status/1369888142711472130/photo/1
# [twitter] 1369888142711472130: Downloading guest token
# [twitter] 1369888142711472130: Downloading JSON metadata
# [download] gifs\16_1369888135593742340.mp4 has already been downloaded
# [download] 100% of 55.57KiB
# [generic] bkuWlH23BZ: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] bkuWlH23BZ: Downloading webpage
# [generic] bkuWlH23BZ: Extracting information
# [redirect] Following redirect to https://twitter.com/rbreich/status/1369741535458197506
# [twitter] 1369741535458197506: Downloading guest token
# [twitter] 1369741535458197506: Downloading JSON metadata
# ERROR: There's no video in this tweet.; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# Could Not Download File
# [generic] gZK9uinrVk: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] gZK9uinrVk: Downloading webpage
# [generic] gZK9uinrVk: Extracting information
# [redirect] Following redirect to https://twitter.com/mtgreenee/status/1369787792058941441
# [twitter] 1369787792058941441: Downloading guest token
# [twitter] 1369787792058941441: Downloading JSON metadata
# ERROR: There's no video in this tweet.; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# Could Not Download File
# [generic] Eb6lq16kJO: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] Eb6lq16kJO: Downloading webpage
# [generic] Eb6lq16kJO: Extracting information
# [redirect] Following redirect to https://twitter.com/frankie_tech/status/1369796031504773120/photo/1
# [twitter] 1369796031504773120: Downloading guest token
# [twitter] 1369796031504773120: Downloading JSON metadata
# [download] gifs\16_1369796018795999236.mp4 has already been downloaded
# [download] 100% of 74.16KiB
# [generic] F6YUQ8mLjE: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] F6YUQ8mLjE: Downloading webpage
# [generic] F6YUQ8mLjE: Extracting information
# [redirect] Following redirect to https://twitter.com/blurmore/status/1369795408248119297/photo/1
# [twitter] 1369795408248119297: Downloading guest token
# [twitter] 1369795408248119297: Downloading JSON metadata
# [download] gifs\16_1369795401293967365.mp4 has already been downloaded
# [download] 100% of 53.66KiB
# [generic] nzDJgzamCn: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] nzDJgzamCn: Downloading webpage
# [generic] nzDJgzamCn: Extracting information
# [redirect] Following redirect to https://twitter.com/EMBII4U/status/1369788148427948036/photo/1
# [twitter] 1369788148427948036: Downloading guest token
# [twitter] 1369788148427948036: Downloading JSON metadata
# [download] gifs\16_1369788142476230667.mp4 has already been downloaded
# [download] 100% of 12.97KiB
# [generic] dBjrmSqbCG: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] dBjrmSqbCG: Downloading webpage
# [generic] dBjrmSqbCG: Extracting information
# [redirect] Following redirect to https://twitter.com/DramaTweetBrad/status/1369787521450848257/photo/1
# [twitter] 1369787521450848257: Downloading guest token
# [twitter] 1369787521450848257: Downloading JSON metadata
# [download] gifs\16_1369787514454745089.mp4 has already been downloaded
# [download] 100% of 42.97KiB
# [generic] 5KGvBBOWC1: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 5KGvBBOWC1: Downloading webpage
# [generic] 5KGvBBOWC1: Extracting information
# [redirect] Following redirect to https://twitter.com/MicheleLeeKoz/status/1369759855788122114/photo/1
# [twitter] 1369759855788122114: Downloading guest token
# [twitter] 1369759855788122114: Downloading JSON metadata
# [download] gifs\16_1369759830861348864.mp4 has already been downloaded
# [download] 100% of 197.29KiB
# 200
# [generic] zmp3e1VPVL: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] zmp3e1VPVL: Downloading webpage
# [generic] zmp3e1VPVL: Extracting information
# [redirect] Following redirect to https://twitter.com/sligo79/status/1369723687226793987/photo/1
# [twitter] 1369723687226793987: Downloading guest token
# [twitter] 1369723687226793987: Downloading JSON metadata
# [download] gifs\16_1369723678120939521.mp4 has already been downloaded
# [download] 100% of 18.72KiB
# [generic] 7g1Ck79RNp: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 7g1Ck79RNp: Downloading webpage
# [generic] 7g1Ck79RNp: Extracting information
# [redirect] Following redirect to https://twitter.com/killerbeezzz_4/status/1369714491152166912/photo/1
# [twitter] 1369714491152166912: Downloading guest token
# [twitter] 1369714491152166912: Downloading JSON metadata
# [download] gifs\16_1369714485624070146.mp4 has already been downloaded
# [download] 100% of 78.12KiB
# [generic] Ap4jVQs0Tg: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] Ap4jVQs0Tg: Downloading webpage
# [generic] Ap4jVQs0Tg: Extracting information
# [redirect] Following redirect to https://twitter.com/therecount/status/1369638712192233481
# [twitter] 1369638712192233481: Downloading guest token
# [twitter] 1369638712192233481: Downloading JSON metadata
# [twitter] 1369638712192233481: Downloading m3u8 information
# [download] gifs\16_1369713009891885056.mp4 has already been downloaded
# [download] 100% of 726.81KiB
# [generic] Qrkjh4h6KS: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] Qrkjh4h6KS: Downloading webpage
# [generic] Qrkjh4h6KS: Extracting information
# [redirect] Following redirect to https://twitter.com/mrsimonkp/status/1369684684121210887/photo/1
# [twitter] 1369684684121210887: Downloading guest token
# [twitter] 1369684684121210887: Downloading JSON metadata
# [download] gifs\16_1369684678517678083.mp4 has already been downloaded
# [download] 100% of 17.16KiB
# [generic] KRemLWJdG5: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] KRemLWJdG5: Downloading webpage
# [generic] KRemLWJdG5: Extracting information
# [redirect] Following redirect to https://twitter.com/lustfortanya/status/1369542455952080899/photo/1
# [twitter] 1369542455952080899: Downloading guest token
# [twitter] 1369542455952080899: Downloading JSON metadata
# [download] gifs\16_1369542450495299586.mp4 has already been downloaded
# [download] 100% of 68.87KiB
# [generic] 7AMQQz3OVX: Requesting header
# WARNING: Falling back on generic information extractor.
# [generic] 7AMQQz3OVX: Downloading webpage
# [generic] 7AMQQz3OVX: Extracting information
# [redirect] Following redirect to https://twitter.com/meredithove/status/1369541887959384066/photo/1
# [twitter] 1369541887959384066: Downloading guest token
# [twitter] 1369541887959384066: Downloading JSON metadata
# [download] gifs\16_1369541880065757184.mp4 has already been downloaded
# [download] 100% of 3.51KiB

# %%
df
# Out:
#                 Tweet ID               Media Key                Tweet URL  \
# 0    1371972970961371139  16_1371972960265908229  https://t.co/n1oU3XlnxI
# 1    1371925808734945280  16_1371925802229637129  https://t.co/4t4mBvLE5I
# 2    1371909563490967557  16_1371909557786701826  https://t.co/EqHXb6qeYS
# 3    1371899134446342145  16_1371899128003842059  https://t.co/ebKdZmlSkz
# 4    1371874398517391362  16_1371874388929220611  https://t.co/QgdmNH2dxw
# ..                   ...                     ...                      ...
# 179  1369714491152166912  16_1369714485624070146  https://t.co/7g1Ck79RNp
# 180  1369713015524843521  16_1369713009891885056  https://t.co/Ap4jVQs0Tg
# 181  1369684684121210887  16_1369684678517678083  https://t.co/Qrkjh4h6KS
# 182  1369542455952080899  16_1369542450495299586  https://t.co/KRemLWJdG5
# 183  1369541887959384066  16_1369541880065757184  https://t.co/7AMQQz3OVX
#
#                                             Tweet Text  \
# 0    Now mitch trubisky doesn't suck? Love all thes...
# 1    I'll be a happy husband for that deserving wif...
# 2    @CamHeyward @Bud_Dupree The @steelers are show...
# 3    Telling. The previous GIF is actually from #AB...
# 4    Stache season isn’t the same without spring br...
# ..                                                 ...
# 179  @deadliquorstore @RepLizCheney @All435Reps Rig...
# 180  @SenMikeLee realizes that even Satan has given...
# 181  @LouGarza86 We are America, were you  can actu...
# 182  @HE4BARBIE @clydesblair @jansARTPOP @CaseForTh...
# 183                 Today’s mood ... #sad #bed #alone
#
#                       GIF Title
# 0    16_1371972960265908229.mp4
# 1    16_1371925802229637129.mp4
# 2    16_1371909557786701826.mp4
# 3    16_1371899128003842059.mp4
# 4    16_1371874388929220611.mp4
# ..                          ...
# 179  16_1369714485624070146.mp4
# 180  16_1369713009891885056.mp4
# 181  16_1369684678517678083.mp4
# 182  16_1369542450495299586.mp4
# 183  16_1369541880065757184.mp4
#
# [184 rows x 5 columns]

# %%
nextToken = data["meta"]["next_token"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d5c28a544552> in <module>
# ----> 1 nextToken = data["meta"]["next_token"]
#
# NameError: name 'data' is not defined
