# %%
import pandas as pd

# %%
happy_df = pd.read_csv("./Raw/happiness.csv", low_memory=False, delimiter=',')
happy_df.head()
# Out:
#                 user_id             status_id           created_at  \
# 0  x1256981810476650496  x1371632070112374785  2021-03-16 01:19:03
# 1           x1522502707  x1371632002860904453  2021-03-16 01:18:47
# 2           x1522502707  x1369109013095358465  2021-03-09 02:13:20
# 3           x1522502707  x1370183993627348997  2021-03-12 01:24:55
# 4             x18075019  x1370015604019761163  2021-03-11 14:15:48
#
#        screen_name                                               text  \
# 0  NeenaSh37687325  You are beautiful as you are❣❣.#beautiful #gor...
# 1         SashkaCo  Girls just wanna have sun.🌊🌞\n#sashkaco #handm...
# 2         SashkaCo  Peace begins with a smile.😊🌴🌊\n#SashkaCo #hand...
# 3         SashkaCo  Stay close to what keeps you feeling alive.💖😊\...
# 4          SRDHAIN  Prem Rawat \n\n#PremRawat #timelesstoday #peac...
#
#                 source  display_text_width reply_to_status_id  \
# 0  Twitter for Android                 277                NaN
# ...

# %%
df=happy_df[['text', 'media_url']] #select only text and media_url
df=df[df['media_url'].notna()] #select only rows without nan value
df=df[df['media_url'].notna()]
# Out:
#                                                    text  \
# 0     You are beautiful as you are❣❣.#beautiful #gor...
# 1     Girls just wanna have sun.🌊🌞\n#sashkaco #handm...
# 2     Peace begins with a smile.😊🌴🌊\n#SashkaCo #hand...
# 3     Stay close to what keeps you feeling alive.💖😊\...
# 11    Prem Rawat \n\n#PremRawat #timelesstoday #peac...
# ...                                                 ...
# 9995  #sociopool #india #official #selfmade #respect...
# 9996  Start 𝘦𝘷𝘦𝘳𝘺 𝘥𝘢𝘺 with an 𝗔𝗧𝗧𝗜𝗧𝗨𝗗𝗘 of 𝗚𝗥𝗔𝗧𝗜𝗧𝗨𝗗𝗘!...
# 9997  May each and every moment of your day be fille...
# 9998  The empowered woman is powerful beyond measure...
# 9999  March is Optimism Month! Everyone feels a bit ...
#
#                                            media_url
# 0     http://pbs.twimg.com/media/EwkEF6rVEAMy1_y.jpg
# 1     http://pbs.twimg.com/media/EwkD8EEUYAAND7R.jpg
# 2     http://pbs.twimg.com/media/EwAKXWmU8AAg7ns.jpg
# 3     http://pbs.twimg.com/media/EwPc4QaUcAIoRcN.jpg
# ...

# %%
df['media_url'].str.contains('.jpg')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 11      True
#         ...
# 9995    True
# 9996    True
# 9997    True
# 9998    True
# 9999    True
# Name: media_url, Length: 6076, dtype: bool

# %%
df[df['media_url']=='http://abs.twimg.com/images/themes/theme14/bg.gif']
# Out:
# Empty DataFrame
# Columns: [text, media_url]
# Index: []

# %%
happy_df.columns
# Out:
# Index(['user_id', 'status_id', 'created_at', 'screen_name', 'text', 'source',
#        'display_text_width', 'reply_to_status_id', 'reply_to_user_id',
#        'reply_to_screen_name', 'is_quote', 'is_retweet', 'favorite_count',
#        'retweet_count', 'quote_count', 'reply_count', 'hashtags', 'symbols',
#        'urls_url', 'urls_t.co', 'urls_expanded_url', 'media_url', 'media_t.co',
#        'media_expanded_url', 'media_type', 'ext_media_url', 'ext_media_t.co',
#        'ext_media_expanded_url', 'ext_media_type', 'mentions_user_id',
#        'mentions_screen_name', 'lang', 'quoted_status_id', 'quoted_text',
#        'quoted_created_at', 'quoted_source', 'quoted_favorite_count',
#        'quoted_retweet_count', 'quoted_user_id', 'quoted_screen_name',
#        'quoted_name', 'quoted_followers_count', 'quoted_friends_count',
#        'quoted_statuses_count', 'quoted_location', 'quoted_description',
#        'quoted_verified', 'retweet_status_id', 'retweet_text',
# ...

# %%
happy_df['media_expanded_url'].str.contains('.jpg')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4         NaN
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: media_expanded_url, Length: 10000, dtype: object
